# %%
import json
import uuid
from sqlalchemy import create_engine

from utils import reset_db, get_session, model_to_dict
from data.models import udahub

# %% [markdown]
# # Udahub Application

# %% [markdown]
# ## Core Database

# %% [markdown]
# **Init DB**

# %%
udahub_db = "data/core/udahub.db"

# %%
reset_db(udahub_db)
# Out:
# ✅ Removed existing data/core/udahub.db
# 2025-11-05 23:25:37,401 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-05 23:25:37,401 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("accounts")
# 2025-11-05 23:25:37,401 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,402 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("accounts")
# 2025-11-05 23:25:37,402 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,402 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("users")
# 2025-11-05 23:25:37,402 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,402 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("users")
# 2025-11-05 23:25:37,403 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,403 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("tickets")
# 2025-11-05 23:25:37,403 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,403 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("tickets")
# 2025-11-05 23:25:37,403 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,403 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("ticket_metadata")
# 2025-11-05 23:25:37,404 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,404 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("ticket_metadata")
# 2025-11-05 23:25:37,404 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,404 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("ticket_messages")
# 2025-11-05 23:25:37,405 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,405 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("ticket_messages")
# 2025-11-05 23:25:37,405 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,405 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("knowledge")
# 2025-11-05 23:25:37,405 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,406 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("knowledge")
# 2025-11-05 23:25:37,406 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,406 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("user_preferences")
# 2025-11-05 23:25:37,406 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,406 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("user_preferences")
# 2025-11-05 23:25:37,406 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,406 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("ticket_resolutions")
# 2025-11-05 23:25:37,407 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,407 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("ticket_resolutions")
# 2025-11-05 23:25:37,407 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,407 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("conversation_summaries")
# 2025-11-05 23:25:37,407 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,407 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("conversation_summaries")
# 2025-11-05 23:25:37,407 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-11-05 23:25:37,408 INFO sqlalchemy.engine.Engine
# CREATE TABLE accounts (
# 	account_id VARCHAR NOT NULL,
# 	account_name VARCHAR NOT NULL,
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (account_id)
# )
#
#
# 2025-11-05 23:25:37,408 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-11-05 23:25:37,409 INFO sqlalchemy.engine.Engine
# CREATE TABLE users (
# 	user_id VARCHAR NOT NULL,
# 	account_id VARCHAR NOT NULL,
# 	external_user_id VARCHAR NOT NULL,
# 	user_name VARCHAR NOT NULL,
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (user_id),
# 	CONSTRAINT uq_user_external_per_account UNIQUE (account_id, external_user_id),
# 	FOREIGN KEY(account_id) REFERENCES accounts (account_id)
# )
#
#
# 2025-11-05 23:25:37,409 INFO sqlalchemy.engine.Engine [no key 0.00012s] ()
# 2025-11-05 23:25:37,409 INFO sqlalchemy.engine.Engine
# CREATE TABLE knowledge (
# 	article_id VARCHAR NOT NULL,
# 	account_id VARCHAR NOT NULL,
# 	title VARCHAR NOT NULL,
# 	content TEXT NOT NULL,
# 	tags TEXT,
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (article_id),
# 	FOREIGN KEY(account_id) REFERENCES accounts (account_id)
# )
#
#
# 2025-11-05 23:25:37,410 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-11-05 23:25:37,410 INFO sqlalchemy.engine.Engine
# CREATE TABLE tickets (
# 	ticket_id VARCHAR NOT NULL,
# 	account_id VARCHAR NOT NULL,
# 	user_id VARCHAR NOT NULL,
# 	channel VARCHAR,
# 	created_at DATETIME,
# 	PRIMARY KEY (ticket_id),
# 	FOREIGN KEY(account_id) REFERENCES accounts (account_id),
# 	FOREIGN KEY(user_id) REFERENCES users (user_id)
# )
#
#
# 2025-11-05 23:25:37,410 INFO sqlalchemy.engine.Engine [no key 0.00011s] ()
# 2025-11-05 23:25:37,411 INFO sqlalchemy.engine.Engine
# CREATE TABLE user_preferences (
# 	preference_id VARCHAR NOT NULL,
# 	user_id VARCHAR NOT NULL,
# 	preference_key VARCHAR NOT NULL,
# 	preference_value VARCHAR NOT NULL,
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (preference_id),
# 	FOREIGN KEY(user_id) REFERENCES users (user_id)
# )
#
#
# 2025-11-05 23:25:37,411 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-11-05 23:25:37,412 INFO sqlalchemy.engine.Engine
# CREATE TABLE ticket_metadata (
# 	ticket_id VARCHAR NOT NULL,
# 	status VARCHAR NOT NULL,
# 	main_issue_type VARCHAR,
# 	tags TEXT,
# 	created_at DATETIME,
# 	updated_at DATETIME,
# 	PRIMARY KEY (ticket_id),
# 	FOREIGN KEY(ticket_id) REFERENCES tickets (ticket_id)
# )
#
#
# 2025-11-05 23:25:37,412 INFO sqlalchemy.engine.Engine [no key 0.00013s] ()
# 2025-11-05 23:25:37,413 INFO sqlalchemy.engine.Engine
# CREATE TABLE ticket_messages (
# 	message_id VARCHAR NOT NULL,
# 	ticket_id VARCHAR NOT NULL,
# 	role VARCHAR(6) NOT NULL,
# 	content TEXT,
# 	created_at DATETIME,
# 	PRIMARY KEY (message_id),
# 	FOREIGN KEY(ticket_id) REFERENCES tickets (ticket_id)
# )
#
#
# 2025-11-05 23:25:37,413 INFO sqlalchemy.engine.Engine [no key 0.00019s] ()
# 2025-11-05 23:25:37,413 INFO sqlalchemy.engine.Engine
# CREATE TABLE ticket_resolutions (
# 	resolution_id VARCHAR NOT NULL,
# 	ticket_id VARCHAR NOT NULL,
# 	resolution_method VARCHAR NOT NULL,
# 	confidence VARCHAR NOT NULL,
# 	articles_used TEXT,
# 	tool_results TEXT,
# 	created_at DATETIME,
# 	PRIMARY KEY (resolution_id),
# 	FOREIGN KEY(ticket_id) REFERENCES tickets (ticket_id)
# )
#
#
# 2025-11-05 23:25:37,414 INFO sqlalchemy.engine.Engine [no key 0.00018s] ()
# 2025-11-05 23:25:37,414 INFO sqlalchemy.engine.Engine
# CREATE TABLE conversation_summaries (
# 	summary_id VARCHAR NOT NULL,
# 	ticket_id VARCHAR NOT NULL,
# 	summary TEXT NOT NULL,
# 	key_points TEXT,
# 	message_count VARCHAR NOT NULL,
# 	created_at DATETIME,
# 	PRIMARY KEY (summary_id),
# 	FOREIGN KEY(ticket_id) REFERENCES tickets (ticket_id)
# )
#
#
# 2025-11-05 23:25:37,414 INFO sqlalchemy.engine.Engine [no key 0.00017s] ()
# 2025-11-05 23:25:37,415 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/core/udahub.db with fresh schema
#    Tables created: accounts, users, tickets, ticket_metadata, ticket_messages, knowledge, user_preferences, ticket_resolutions, conversation_summaries

# %%
engine = create_engine(f"sqlite:///{udahub_db}", echo=False)
udahub.Base.metadata.create_all(bind=engine)

# %% [markdown]
# **Account**

# %%
account_id = "cultpass"
account_name = "CultPass Card"

# %%
with get_session(engine) as session:
    account = udahub.Account(
        account_id=account_id,
        account_name=account_name,
    )
    session.add(account)

# %% [markdown]
# ## Integrations

# %% [markdown]
# **Knowledge Base**

# %%
# TODO: Create additional 10 articles

# %%
cultpass_articles = []

with open('data/external/cultpass_articles.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_articles.append(json.loads(line))

# %%
cultpass_articles
# Out:
# [{'title': 'How to Reserve a Spot for an Event',
#   'content': 'If a user asks how to reserve an event:\n\n- Guide them to the CultPass app\n- Instruct them to browse the experience catalog and tap \'Reserve\'\n- If it\'s a premium or limited event, check if reservation confirmation is required via email\n- Remind them to arrive at least 15 minutes early with their QR code visible\n\n**Suggested phrasing:**\n"You can reserve an experience by opening the CultPass app, selecting your desired event, and tapping \'Reserve\'. Be sure to arrive 15 minutes early with your QR code ready."',
#   'tags': 'reservation, events, booking, attendance'},
#  {'title': "What's Included in a CultPass Subscription",
#   'content': 'Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."',
#   'tags': 'subscription, benefits, pricing, access'},
#  {'title': 'How to Cancel or Pause a Subscription',
#   'content': 'Users can manage their subscription via the app > \'My Account\' > \'Manage Plan\'.\n\n- Cancel: Effective at the end of the billing cycle\n- Pause: Preserves user data, resumes automatically when reactivated\n- Do NOT offer refunds unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel or pause your subscription at any time via the \'My Account\' section in the CultPass app. Cancelation takes effect at the end of your billing cycle."',
#   'tags': 'cancelation, pause, subscription, billing'},
#  {'title': 'How to Handle Login Issues?',
#   'content': 'Most login issues are resolved with password reset:\n\n- Ask the user to tap \'Forgot Password\' on the login screen\n- Ensure they are using the correct registered email\n- If they did not receive the reset email, check spam folder or retry after 10 minutes\n- For persistent login issues, escalate to human support\n\n**Suggested phrasing:**\n"Try tapping \'Forgot Password\' on the login screen. Make sure you\'re using the email associated with your account. If the email doesn\'t arrive, check spam or try again in a few minutes."',
#   'tags': 'login, password, access, escalation'},
#  {'title': 'What to Do When the CultPass App Crashes',
#   'content': 'If a user reports app crashes or freezing:\n\n- Force quit the app completely and reopen\n- Clear app cache via device settings\n- Ensure device meets minimum requirements (iOS 14+ or Android 10+)\n- Check that latest app version is installed via App Store/Play Store\n- Try uninstalling and reinstalling the app\n- Restart the device\n- For persistent crashes, escalate to technical support with device model and OS version\n\n**Suggested phrasing:**\n"Let\'s try a few quick fixes. First, force close the app and reopen it. If that doesn\'t work, clear the app cache in your device settings or try reinstalling. Make sure you\'re running the latest version from the App Store."',
#   'tags': 'technical, app, crash, performance, troubleshooting'},
#  {'title': 'QR Code Not Scanning at Event Venue',
#   'content': 'If a user cannot scan their QR code at a venue:\n\n- Increase screen brightness to maximum\n- Ensure the full QR code is visible on screen (not cut off)\n- Check that device has active internet connection\n- Try refreshing the reservation in the app\n- Show booking confirmation email as backup verification\n- Inform user that venue staff can manually verify reservation using booking number\n- For persistent QR code issues, check if QR code expired (events pass check-in window)\n\n**Suggested phrasing:**\n"Try increasing your screen brightness and make sure the entire QR code is visible. If it still won\'t scan, show the venue staff your booking confirmation email—they can verify your reservation manually."',
#   'tags': 'qr code, technical, venue, attendance, booking'},
#  {'title': 'App Running Slowly or Not Loading',
#   'content': 'If a user experiences slow performance or loading issues:\n\n- Check internet connection strength (try switching between WiFi and mobile data)\n- Close other background apps to free up memory\n- Clear app cache via device settings\n- Check for app updates in App Store/Play Store\n- Restart the device\n- Note that experience catalog may load slowly during peak hours (evenings and weekends)\n- If specific pages won\'t load, try logging out and back in\n\n**Suggested phrasing:**\n"I understand that\'s frustrating. Let\'s try checking your internet connection first, then clearing the app cache. The catalog can be slower during peak hours, but these steps should help speed things up."',
#   'tags': 'technical, performance, loading, connection, troubleshooting'},
#  {'title': 'How to Update Payment Information',
#   'content': 'To update payment methods:\n\n- Navigate to My Account > Payment Methods in the app\n- Tap \'Add Payment Method\' to add new card\n- Select existing card and tap \'Remove\' to delete\n- Set default payment method by selecting card and tapping \'Set as Default\'\n- Changes apply to next billing cycle\n- Security note: CultPass never stores full card numbers, only encrypted tokens\n- Card verification may be required for new cards\n\n**Suggested phrasing:**\n"You can update your payment information by going to My Account, then Payment Methods. Add or remove cards there, and set your preferred default. Don\'t worry—we only store encrypted payment tokens, never your full card number."',
#   'tags': 'billing, payment, credit card, account, security'},
#  {'title': 'What Happens When a Payment Fails',
#   'content': 'When a payment fails:\n\n- Account is temporarily suspended until payment issue is resolved\n- User receives email notification about failed payment\n- 7-day grace period provided to update payment method\n- User can retry payment manually via My Account > Billing > Retry Payment\n- During suspension, new reservations are not allowed (existing reservations remain valid)\n- Once payment succeeds, account is immediately reactivated\n- Repeated payment failures may result in account closure\n\n**Suggested phrasing:**\n"Your payment didn\'t go through, so your account is temporarily suspended. You have 7 days to update your payment method in My Account. Once updated, you can retry the payment and your access will be restored immediately."',
#   'tags': 'billing, payment, failed, suspension, account'},
#  {'title': 'How to Download Invoices and Receipts',
#   'content': 'To access billing documents:\n\n- Navigate to My Account > Billing History in the app\n- Tap any month to download PDF invoice\n- Receipts are automatically sent via email after each charge\n- Check spam folder if receipt email not received\n- Invoices include subscription tier details and any premium event charges\n- Historical invoices available for up to 24 months\n- For tax purposes, annual summary available in January\n\n**Suggested phrasing:**\n"You can download invoices anytime from My Account under Billing History. Receipts are also emailed automatically after each charge—check your spam folder if you haven\'t received them."',
#   'tags': 'billing, invoice, receipt, payment, history'},
#  {'title': 'How to Update Your Profile Details',
#   'content': 'To update profile information:\n\n- Navigate to My Account > Profile in the app\n- Edit name, email, phone number, and notification preferences\n- Email changes require verification via confirmation link\n- Phone number is used for event reminders and booking confirmations\n- Name on profile should match government ID for age-restricted events\n- Profile photo is optional but helps personalize experience\n- Changes save automatically when you tap \'Save\'\n\n**Suggested phrasing:**\n"You can update your profile by going to My Account and selecting Profile. Just remember that email changes need verification, and your name should match your ID for any age-restricted events."',
#   'tags': 'account, profile, email, phone, settings'},
#  {'title': 'How to Delete Your CultPass Account',
#   'content': 'To permanently delete your account:\n\n- Navigate to My Account > Privacy & Security > Delete Account\n- Active subscriptions must be cancelled first\n- Confirm deletion by entering password\n- All personal data will be deleted within 30 days per GDPR requirements\n- Unused monthly quota is forfeited upon deletion\n- Account deletion is permanent and cannot be undone\n- Deletion confirmation sent via email\n- You can create new account later with same email after 30 days\n\n**Suggested phrasing:**\n"To delete your account, go to My Account, then Privacy & Security, and select Delete Account. Please note this is permanent and all your data will be removed within 30 days. Make sure to cancel any active subscriptions first."',
#   'tags': 'account, deletion, privacy, gdpr, security'},
#  {'title': 'How to Change Your Subscription Tier',
#   'content': 'CultPass offers three subscription tiers:\n\n- Basic: 4 events per month (₹299/month)\n- Premium: 8 events per month + priority booking (₹549/month)\n- VIP: Unlimited events + exclusive experiences (₹999/month)\n\nTo change tiers:\n- Navigate to My Account > Manage Plan > Change Tier\n- Select desired tier and confirm\n- Upgrades take effect immediately with prorated charge\n- Downgrades take effect at next billing cycle\n- Unused quota does not roll over when changing tiers\n- Can change tier once per billing cycle\n\n**Suggested phrasing:**\n"You can change your subscription tier in My Account under Manage Plan. Upgrades happen right away with a prorated charge, while downgrades take effect next billing cycle. Keep in mind unused events don\'t carry over."',
#   'tags': 'subscription, tier, upgrade, downgrade, pricing, benefits'},
#  {'title': 'Cancelling a Reservation and Refund Policy',
#   'content': 'Cancellation and refund policy:\n\n- Free cancellation up to 24 hours before event start time\n- Cancellations within 24 hours forfeit the monthly quota slot (no refund)\n- No-shows count as used quota and are not refunded\n- Premium events with additional fees are refundable only if cancelled 48+ hours in advance\n- To cancel: Open reservation > Tap Cancel > Confirm cancellation\n- Quota is restored immediately for eligible cancellations (24+ hours notice)\n- Cancellation confirmation sent via email and app notification\n- Important: Do NOT offer refunds for subscription fees unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel your reservation for free if you do it at least 24 hours before the event. Just open the reservation and tap Cancel. Your monthly quota will be restored immediately. For premium events with extra fees, you\'ll need to cancel 48 hours ahead for a refund."',
#   'tags': 'cancellation, refund, policy, booking, reservation, quota'}]

# %%
if len(cultpass_articles) < 14:
    raise AssertionError("You should load the articles with at least 14 records")

# %%
with get_session(engine) as session:
    kb = []
    for article in cultpass_articles:
        knowledge = udahub.Knowledge(
            article_id=str(uuid.uuid4()),
            account_id=account_id,
            title=article["title"],
            content=article["content"],
            tags=article["tags"]
        )
        kb.append(knowledge)
    session.add_all(kb)

# %% [markdown]
# **Ticket**

# %%
cultpass_users = []

with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %%
ticket_info = {
    "status": "open",
    "content": "I can't log in to my Cultpass account.",
    "owner_id": cultpass_users[0]["id"],
    "owner_name": cultpass_users[0]["name"],
    "role": "user",
    "channel": "chat",
    "tags": "login, access",
}

# %%
with get_session(engine) as session:
    user = session.query(udahub.User).filter_by(
        account_id=account_id,
        external_user_id=ticket_info["owner_id"],
    ).first()

    if not user:
        user = udahub.User(
            user_id=str(uuid.uuid4()),
            account_id=account_id,
            external_user_id=ticket_info["owner_id"],
            user_name=ticket_info["owner_name"],
        )
    
    ticket = udahub.Ticket(
        ticket_id=str(uuid.uuid4()),
        account_id=account_id,
        user_id=user.user_id,
        channel=ticket_info["channel"],
    )
    metadata = udahub.TicketMetadata(
        ticket_id=ticket.ticket_id,
        status=ticket_info["status"],
        main_issue_type=None,
        tags=ticket_info["tags"],
    )

    first_message = udahub.TicketMessage(
        message_id=str(uuid.uuid4()),
        ticket_id=ticket.ticket_id,
        role=ticket_info["role"],
        content=ticket_info["content"],
    )

    session.add_all([user, ticket, metadata, first_message])

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    print(account)
# Out:
# <Account(account_id='cultpass', account_name='CultPass Card')>

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    for article in account.knowledge_articles:
        print(article)
# Out:
# <Knowledge(article_id='c1b1d171-c3b4-4c73-acb3-55621f118c14', title='How to Reserve a Spot for an Event')>
# <Knowledge(article_id='2b33dfe3-c7c0-4eac-a624-ff3261daed38', title='What's Included in a CultPass Subscription')>
# <Knowledge(article_id='e14b72d7-e7d3-4fde-912f-5603bbb59aed', title='How to Cancel or Pause a Subscription')>
# <Knowledge(article_id='98ea4110-1675-4a44-bf46-ae6fdaf002ed', title='How to Handle Login Issues?')>
# <Knowledge(article_id='f3e6dd66-ada1-413f-abdf-9adb2bba890a', title='What to Do When the CultPass App Crashes')>
# <Knowledge(article_id='694a00f7-9a4b-40ee-92fe-112c25508e36', title='QR Code Not Scanning at Event Venue')>
# <Knowledge(article_id='ab71c68e-9f01-462b-9463-0176af3ed9b3', title='App Running Slowly or Not Loading')>
# <Knowledge(article_id='b2925d90-4dc3-4a99-9a97-cd637c82ae1a', title='How to Update Payment Information')>
# <Knowledge(article_id='2e1aa1b8-149a-486c-8579-7ca021d208f0', title='What Happens When a Payment Fails')>
# <Knowledge(article_id='c9f1ec54-7ffd-4bc3-b805-f44c2642f7df', title='How to Download Invoices and Receipts')>
# <Knowledge(article_id='a0e35f0a-81a0-427f-8f0b-03afec90cc57', title='How to Update Your Profile Details')>
# <Knowledge(article_id='b4ad98b0-5214-4172-9ab9-3cf0758e6032', title='How to Delete Your CultPass Account')>
# <Knowledge(article_id='0558aa42-b9b8-4997-9b9c-dbfe7e0006b1', title='How to Change Your Subscription Tier')>
# <Knowledge(article_id='dc196e07-11d2-44fa-99ff-ddc8dcf1a8e2', title='Cancelling a Reservation and Refund Policy')>

# %%
with get_session(engine) as session:
    users = session.query(udahub.User).all()
    for user in users:
        print(user)
# Out:
# <User(user_id='1f0371e4-42b4-49b8-9882-e1f24b5d71da', user_name='Alice Kingsley', external_user_id='a4ab87')>

# %%
with get_session(engine) as session:
    user = session.query(udahub.User).filter_by(
        account_id=account_id,
        external_user_id=ticket_info["owner_id"],
    ).first()
    
    ticket:udahub.Ticket = user.tickets[0]
    for message in ticket.messages:
        print(message)
# Out:
# <TicketMessage(message_id='fc3ff83a-aacd-4bde-b007-478ac367be68', role='user', content='I can't log in to my Cultpass ...')>
